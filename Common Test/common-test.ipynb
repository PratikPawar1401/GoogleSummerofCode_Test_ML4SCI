# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/commontest/dataset/val/no/422.npy
# /kaggle/input/commontest/dataset/val/no/331.npy
# /kaggle/input/commontest/dataset/val/no/2434.npy
# /kaggle/input/commontest/dataset/val/no/280.npy
# /kaggle/input/commontest/dataset/val/no/970.npy
# /kaggle/input/commontest/dataset/val/no/2467.npy
# /kaggle/input/commontest/dataset/val/no/2424.npy
# /kaggle/input/commontest/dataset/val/no/745.npy
# /kaggle/input/commontest/dataset/val/no/100.npy
# /kaggle/input/commontest/dataset/val/no/1200.npy
# /kaggle/input/commontest/dataset/val/no/1170.npy
# /kaggle/input/commontest/dataset/val/no/1876.npy
# /kaggle/input/commontest/dataset/val/no/719.npy
# /kaggle/input/commontest/dataset/val/no/1041.npy
# /kaggle/input/commontest/dataset/val/no/193.npy
# /kaggle/input/commontest/dataset/val/no/1191.npy
# /kaggle/input/commontest/dataset/val/no/461.npy
# /kaggle/input/commontest/dataset/val/no/2196.npy
# /kaggle/input/commontest/dataset/val/no/63.npy
# /kaggle/input/commontest/dataset/val/no/1364.npy
# /kaggle/input/commontest/dataset/val/no/1740.npy
# /kaggle/input/commontest/dataset/val/no/64.npy
# /kaggle/input/commontest/dataset/val/no/2178.npy
# /kaggle/input/commontest/dataset/val/no/1337.npy
# /kaggle/input/commontest/dataset/val/no/1511.npy
# /kaggle/input/commontest/dataset/val/no/253.npy
# /kaggle/input/commontest/dataset/val/no/1916.npy
# /kaggle/input/commontest/dataset/val/no/375.npy
# /kaggle/input/commontest/dataset/val/no/2083.npy
# /kaggle/input/commontest/dataset/val/no/789.npy
# /kaggle/input/commontest/dataset/val/no/949.npy
# /kaggle/input/commontest/dataset/val/no/308.npy
# /kaggle/input/commontest/dataset/val/no/679.npy
# /kaggle/input/commontest/dataset/val/no/1778.npy
# /kaggle/input/commontest/dataset/val/no/1702.npy
# /kaggle/input/commontest/dataset/val/no/941.npy
# /kaggle/input/commontest/dataset/val/no/330.npy
# /kaggle/input/commontest/dataset/val/no/2321.npy
# /kaggle/input/commontest/dataset/val/no/1940.npy
# /kaggle/input/commontest/dataset/val/no/1188.npy
# /kaggle/input/commontest/dataset/val/no/693.npy
# /kaggle/input/commontest/dataset/val/no/267.npy
# /kaggle/input/commontest/dataset/val/no/91.npy
# /kaggle/input/commontest/dataset/val/no/1965.npy
# /kaggle/input/commontest/dataset/val/no/1019.npy
# /kaggle/input/commontest/dataset/val/no/290.npy
# /kaggle/input/commontest/dataset/val/no/464.npy
# /kaggle/input/commontest/dataset/val/no/2442.npy
# /kaggle/input/commontest/dataset/val/no/1600.npy
# /kaggle/input/commontest/dataset/val/no/1479.npy
# /kaggle/input/commontest/dataset/val/no/1932.npy
# /kaggle/input/commontest/dataset/val/no/122.npy
# /kaggle/input/commontest/dataset/val/no/2098.npy
# /kaggle/input/commontest/dataset/val/no/1994.npy
# /kaggle/input/commontest/dataset/val/no/1946.npy
# /kaggle/input/commontest/dataset/val/no/853.npy
# /kaggle/input/commontest/dataset/val/no/202.npy
# /kaggle/input/commontest/dataset/val/no/995.npy
# /kaggle/input/commontest/dataset/val/no/840.npy
# /kaggle/input/commontest/dataset/val/no/188.npy
# /kaggle/input/commontest/dataset/val/no/1175.npy
# /kaggle/input/commontest/dataset/val/no/1058.npy
# /kaggle/input/commontest/dataset/val/no/407.npy
# /kaggle/input/commontest/dataset/val/no/491.npy
# /kaggle/input/commontest/dataset/val/no/2114.npy
# /kaggle/input/commontest/dataset/val/no/1588.npy
# /kaggle/input/commontest/dataset/val/no/1721.npy
# /kaggle/input/commontest/dataset/val/no/2160.npy
# /kaggle/input/commontest/dataset/val/no/1204.npy
# /kaggle/input/commontest/dataset/val/no/489.npy
# /kaggle/input/commontest/dataset/val/no/2013.npy
# /kaggle/input/commontest/dataset/val/no/1770.npy
# /kaggle/input/commontest/dataset/val/no/844.npy
# /kaggle/input/commontest/dataset/val/no/481.npy
# /kaggle/input/commontest/dataset/val/no/1138.npy
# /kaggle/input/commontest/dataset/val/no/499.npy
# /kaggle/input/commontest/dataset/val/no/1819.npy
# /kaggle/input/commontest/dataset/val/no/945.npy
# /kaggle/input/commontest/dataset/val/no/1489.npy
# /kaggle/input/commontest/dataset/val/no/1426.npy
# /kaggle/input/commontest/dataset/val/no/185.npy
# /kaggle/input/commontest/dataset/val/no/1873.npy
# /kaggle/input/commontest/dataset/val/no/2224.npy
# /kaggle/input/commontest/dataset/val/no/1141.npy
# /kaggle/input/commontest/dataset/val/no/172.npy
# /kaggle/input/commontest/dataset/val/no/1712.npy
# /kaggle/input/commontest/dataset/val/no/2188.npy
# /kaggle/input/commontest/dataset/val/no/1665.npy
# /kaggle/input/commontest/dataset/val/no/1990.npy
# /kaggle/input/commontest/dataset/val/no/1745.npy
# /kaggle/input/commontest/dataset/val/no/544.npy
# /kaggle/input/commontest/dataset/val/no/1273.npy
# /kaggle/input/commontest/dataset/val/no/2243.npy
# /kaggle/input/commontest/dataset/val/no/616.npy
# /kaggle/input/commontest/dataset/val/no/798.npy
# /kaggle/input/commontest/dataset/val/no/1007.npy
# /kaggle/input/commontest/dataset/val/no/1247.npy
# /kaggle/input/commontest/dataset/val/no/479.npy
# /kaggle/input/commontest/dataset/val/no/1463.npy
# /kaggle/input/commontest/dataset/val/no/1203.npy
# /kaggle/input/commontest/dataset/val/no/1455.npy
# /kaggle/input/commontest/dataset/val/no/1348.npy
# /kaggle/input/commontest/dataset/val/no/277.npy
# /kaggle/input/commontest/dataset/val/no/1442.npy
# /kaggle/input/commontest/dataset/val/no/2407.npy
# /kaggle/input/commontest/dataset/val/no/2256.npy
# /kaggle/input/commontest/dataset/val/no/500.npy
# /kaggle/input/commontest/dataset/val/no/47.npy
# /kaggle/input/commontest/dataset/val/no/552.npy
# /kaggle/input/commontest/dataset/val/no/2295.npy
# /kaggle/input/commontest/dataset/val/no/565.npy
# /kaggle/input/commontest/dataset/val/no/1281.npy
# /kaggle/input/commontest/dataset/val/no/320.npy
# /kaggle/input/commontest/dataset/val/no/2249.npy
# /kaggle/input/commontest/dataset/val/no/492.npy
# /kaggle/input/commontest/dataset/val/no/864.npy
# /kaggle/input/commontest/dataset/val/no/1566.npy
# /kaggle/input/commontest/dataset/val/no/1894.npy
# /kaggle/input/commontest/dataset/val/no/1079.npy
# /kaggle/input/commontest/dataset/val/no/2288.npy
# /kaggle/input/commontest/dataset/val/no/1813.npy
# /kaggle/input/commontest/dataset/val/no/2158.npy
# /kaggle/input/commontest/dataset/val/no/740.npy
# /kaggle/input/commontest/dataset/val/no/1235.npy
# /kaggle/input/commontest/dataset/val/no/2237.npy
# /kaggle/input/commontest/dataset/val/no/2379.npy
# /kaggle/input/commontest/dataset/val/no/697.npy
# /kaggle/input/commontest/dataset/val/no/2165.npy
# /kaggle/input/commontest/dataset/val/no/354.npy
# /kaggle/input/commontest/dataset/val/no/1334.npy
# /kaggle/input/commontest/dataset/val/no/1674.npy
# /kaggle/input/commontest/dataset/val/no/1708.npy
# /kaggle/input/commontest/dataset/val/no/1980.npy
# /kaggle/input/commontest/dataset/val/no/2152.npy
# /kaggle/input/commontest/dataset/val/no/2291.npy
# /kaggle/input/commontest/dataset/val/no/1113.npy
# /kaggle/input/commontest/dataset/val/no/1952.npy
# /kaggle/input/commontest/dataset/val/no/23.npy
# /kaggle/input/commontest/dataset/val/no/1671.npy
# /kaggle/input/commontest/dataset/val/no/1014.npy
# /kaggle/input/commontest/dataset/val/no/68.npy
# /kaggle/input/commontest/dataset/val/no/1601.npy
# /kaggle/input/commontest/dataset/val/no/1221.npy
# /kaggle/input/commontest/dataset/val/no/2306.npy
# /kaggle/input/commontest/dataset/val/no/2399.npy
# /kaggle/input/commontest/dataset/val/no/756.npy
# /kaggle/input/commontest/dataset/val/no/1177.npy
# /kaggle/input/commontest/dataset/val/no/925.npy
# /kaggle/input/commontest/dataset/val/no/224.npy
# /kaggle/input/commontest/dataset/val/no/1210.npy
# /kaggle/input/commontest/dataset/val/no/1212.npy
# /kaggle/input/commontest/dataset/val/no/1838.npy
# /kaggle/input/commontest/dataset/val/no/1469.npy
# /kaggle/input/commontest/dataset/val/no/1500.npy
# /kaggle/input/commontest/dataset/val/no/109.npy
# /kaggle/input/commontest/dataset/val/no/1768.npy
# /kaggle/input/commontest/dataset/val/no/1960.npy
# /kaggle/input/commontest/dataset/val/no/1385.npy
# /kaggle/input/commontest/dataset/val/no/1414.npy
# /kaggle/input/commontest/dataset/val/no/1238.npy
# /kaggle/input/commontest/dataset/val/no/432.npy
# /kaggle/input/commontest/dataset/val/no/1225.npy
# /kaggle/input/commontest/dataset/val/no/1822.npy
# /kaggle/input/commontest/dataset/val/no/69.npy
# /kaggle/input/commontest/dataset/val/no/45.npy
# /kaggle/input/commontest/dataset/val/no/1577.npy
# /kaggle/input/commontest/dataset/val/no/911.npy
# /kaggle/input/commontest/dataset/val/no/1472.npy
# /kaggle/input/commontest/dataset/val/no/832.npy
# /kaggle/input/commontest/dataset/val/no/2086.npy
# /kaggle/input/commontest/dataset/val/no/675.npy
# /kaggle/input/commontest/dataset/val/no/2034.npy
# /kaggle/input/commontest/dataset/val/no/99.npy
# /kaggle/input/commontest/dataset/val/no/726.npy
# /kaggle/input/commontest/dataset/val/no/1645.npy
# /kaggle/input/commontest/dataset/val/no/2298.npy
# /kaggle/input/commontest/dataset/val/no/1398.npy
# /kaggle/input/commontest/dataset/val/no/1884.npy
# /kaggle/input/commontest/dataset/val/no/1563.npy
# /kaggle/input/commontest/dataset/val/no/1851.npy
# /kaggle/input/commontest/dataset/val/no/734.npy
# /kaggle/input/commontest/dataset/val/no/536.npy
# /kaggle/input/commontest/dataset/val/no/2176.npy
# /kaggle/input/commontest/dataset/val/no/2307.npy
# /kaggle/input/commontest/dataset/val/no/2498.npy
# /kaggle/input/commontest/dataset/val/no/1699.npy
# /kaggle/input/commontest/dataset/val/no/1801.npy
# /kaggle/input/commontest/dataset/val/no/2042.npy
# /kaggle/input/commontest/dataset/val/no/1691.npy
# /kaggle/input/commontest/dataset/val/no/1534.npy
# /kaggle/input/commontest/dataset/val/no/1458.npy
# /kaggle/input/commontest/dataset/val/no/553.npy
# /kaggle/input/commontest/dataset/val/no/1101.npy
# /kaggle/input/commontest/dataset/val/no/759.npy
# /kaggle/input/commontest/dataset/val/no/646.npy
# /kaggle/input/commontest/dataset/val/no/1202.npy
# /kaggle/input/commontest/dataset/val/no/1129.npy
# /kaggle/input/commontest/dataset/val/no/768.npy
# /kaggle/input/commontest/dataset/val/no/1912.npy
# /kaggle/input/commontest/dataset/val/no/1097.npy
# /kaggle/input/commontest/dataset/val/no/2493.npy
# /kaggle/input/commontest/dataset/val/no/1681.npy
# /kaggle/input/commontest/dataset/val/no/131.npy
# /kaggle/input/commontest/dataset/val/no/295.npy
# /kaggle/input/commontest/dataset/val/no/1108.npy
# /kaggle/input/commontest/dataset/val/no/1981.npy
# /kaggle/input/commontest/dataset/val/no/1208.npy
# /kaggle/input/commontest/dataset/val/no/2263.npy
# /kaggle/input/commontest/dataset/val/no/222.npy
# /kaggle/input/commontest/dataset/val/no/1660.npy
# /kaggle/input/commontest/dataset/val/no/2476.npy
# /kaggle/input/commontest/dataset/val/no/438.npy
# /kaggle/input/commontest/dataset/val/no/831.npy
# /kaggle/input/commontest/dataset/val/no/723.npy
# /kaggle/input/commontest/dataset/val/no/163.npy
# /kaggle/input/commontest/dataset/val/no/2480.npy
# /kaggle/input/commontest/dataset/val/no/2451.npy
# /kaggle/input/commontest/dataset/val/no/10.npy
# /kaggle/input/commontest/dataset/val/no/368.npy
# /kaggle/input/commontest/dataset/val/no/507.npy
# /kaggle/input/commontest/dataset/val/no/316.npy
# /kaggle/input/commontest/dataset/val/no/604.npy
# /kaggle/input/commontest/dataset/val/no/199.npy
# /kaggle/input/commontest/dataset/val/no/440.npy
# /kaggle/input/commontest/dataset/val/no/151.npy
# /kaggle/input/commontest/dataset/val/no/699.npy
# /kaggle/input/commontest/dataset/val/no/2109.npy
# /kaggle/input/commontest/dataset/val/no/1279.npy
# /kaggle/input/commontest/dataset/val/no/412.npy
# /kaggle/input/commontest/dataset/val/no/1661.npy
# /kaggle/input/commontest/dataset/val/no/43.npy
# /kaggle/input/commontest/dataset/val/no/1505.npy
# /kaggle/input/commontest/dataset/val/no/2270.npy
# /kaggle/input/commontest/dataset/val/no/898.npy
# /kaggle/input/commontest/dataset/val/no/1961.npy
# /kaggle/input/commontest/dataset/val/no/1694.npy
# /kaggle/input/commontest/dataset/val/no/234.npy
# /kaggle/input/commontest/dataset/val/no/1122.npy
# /kaggle/input/commontest/dataset/val/no/1927.npy
# /kaggle/input/commontest/dataset/val/no/1037.npy
# /kaggle/input/commontest/dataset/val/no/381.npy
# /kaggle/input/commontest/dataset/val/no/437.npy
# /kaggle/input/commontest/dataset/val/no/571.npy
# /kaggle/input/commontest/dataset/val/no/2192.npy
# /kaggle/input/commontest/dataset/val/no/1788.npy
# /kaggle/input/commontest/dataset/val/no/1389.npy
# /kaggle/input/commontest/dataset/val/no/642.npy
# /kaggle/input/commontest/dataset/val/no/996.npy
# /kaggle/input/commontest/dataset/val/no/1893.npy
# /kaggle/input/commontest/dataset/val/no/1345.npy
# /kaggle/input/commontest/dataset/val/no/107.npy
# /kaggle/input/commontest/dataset/val/no/2297.npy
# /kaggle/input/commontest/dataset/val/no/1753.npy
# /kaggle/input/commontest/dataset/val/no/2269.npy
# /kaggle/input/commontest/dataset/val/no/2359.npy
# /kaggle/input/commontest/dataset/val/no/306.npy
# /kaggle/input/commontest/dataset/val/no/2340.npy
# /kaggle/input/commontest/dataset/val/no/713.npy
# /kaggle/input/commontest/dataset/val/no/1556.npy
# /kaggle/input/commontest/dataset/val/no/695.npy
# /kaggle/input/commontest/dataset/val/no/1347.npy
# /kaggle/input/commontest/dataset/val/no/619.npy
# /kaggle/input/commontest/dataset/val/no/588.npy
# /kaggle/input/commontest/dataset/val/no/346.npy
# /kaggle/input/commontest/dataset/val/no/62.npy
# /kaggle/input/commontest/dataset/val/no/126.npy
# /kaggle/input/commontest/dataset/val/no/1226.npy
# /kaggle/input/commontest/dataset/val/no/514.npy
# /kaggle/input/commontest/dataset/val/no/1244.npy
# /kaggle/input/commontest/dataset/val/no/336.npy
# /kaggle/input/commontest/dataset/val/no/1029.npy
# /kaggle/input/commontest/dataset/val/no/1119.npy
# /kaggle/input/commontest/dataset/val/no/533.npy
# /kaggle/input/commontest/dataset/val/no/933.npy
# /kaggle/input/commontest/dataset/val/no/1311.npy
# /kaggle/input/commontest/dataset/val/no/1453.npy
# /kaggle/input/commontest/dataset/val/no/1689.npy
# /kaggle/input/commontest/dataset/val/no/1963.npy
# /kaggle/input/commontest/dataset/val/no/384.npy
# /kaggle/input/commontest/dataset/val/no/508.npy
# /kaggle/input/commontest/dataset/val/no/1466.npy
# /kaggle/input/commontest/dataset/val/no/1752.npy
# /kaggle/input/commontest/dataset/val/no/315.npy
# /kaggle/input/commontest/dataset/val/no/2088.npy
# /kaggle/input/commontest/dataset/val/no/778.npy
# /kaggle/input/commontest/dataset/val/no/2215.npy
# /kaggle/input/commontest/dataset/val/no/1127.npy
# /kaggle/input/commontest/dataset/val/no/961.npy
# /kaggle/input/commontest/dataset/val/no/1568.npy
# /kaggle/input/commontest/dataset/val/no/2231.npy
# /kaggle/input/commontest/dataset/val/no/1206.npy
# /kaggle/input/commontest/dataset/val/no/2163.npy
# /kaggle/input/commontest/dataset/val/no/2462.npy
# /kaggle/input/commontest/dataset/val/no/447.npy
# /kaggle/input/commontest/dataset/val/no/781.npy
# /kaggle/input/commontest/dataset/val/no/1684.npy
# /kaggle/input/commontest/dataset/val/no/218.npy
# /kaggle/input/commontest/dataset/val/no/1624.npy
# /kaggle/input/commontest/dataset/val/no/1845.npy
# /kaggle/input/commontest/dataset/val/no/1242.npy
# /kaggle/input/commontest/dataset/val/no/2378.npy
# /kaggle/input/commontest/dataset/val/no/737.npy
# /kaggle/input/commontest/dataset/val/no/1036.npy
# /kaggle/input/commontest/dataset/val/no/21.npy
# /kaggle/input/commontest/dataset/val/no/111.npy
# /kaggle/input/commontest/dataset/val/no/1976.npy
# /kaggle/input/commontest/dataset/val/no/784.npy
# /kaggle/input/commontest/dataset/val/no/1506.npy
# /kaggle/input/commontest/dataset/val/no/1258.npy
# /kaggle/input/commontest/dataset/val/no/962.npy
# /kaggle/input/commontest/dataset/val/no/2426.npy
# /kaggle/input/commontest/dataset/val/no/1857.npy
# /kaggle/input/commontest/dataset/val/no/1384.npy
# /kaggle/input/commontest/dataset/val/no/671.npy
# /kaggle/input/commontest/dataset/val/no/692.npy
# /kaggle/input/commontest/dataset/val/no/2077.npy
# /kaggle/input/commontest/dataset/val/no/1766.npy
# /kaggle/input/commontest/dataset/val/no/2128.npy
# /kaggle/input/commontest/dataset/val/no/130.npy
# /kaggle/input/commontest/dataset/val/no/2411.npy
# /kaggle/input/commontest/dataset/val/no/1936.npy
# /kaggle/input/commontest/dataset/val/no/175.npy
# /kaggle/input/commontest/dataset/val/no/2354.npy
# /kaggle/input/commontest/dataset/val/no/1480.npy
# /kaggle/input/commontest/dataset/val/no/1562.npy
# /kaggle/input/commontest/dataset/val/no/2408.npy
# /kaggle/input/commontest/dataset/val/no/195.npy
# /kaggle/input/commontest/dataset/val/no/511.npy
# /kaggle/input/commontest/dataset/val/no/281.npy
# /kaggle/input/commontest/dataset/val/no/408.npy
# /kaggle/input/commontest/dataset/val/no/974.npy
# /kaggle/input/commontest/dataset/val/no/1095.npy
# /kaggle/input/commontest/dataset/val/no/1248.npy
# /kaggle/input/commontest/dataset/val/no/2162.npy
# /kaggle/input/commontest/dataset/val/no/2238.npy
# /kaggle/input/commontest/dataset/val/no/369.npy
# /kaggle/input/commontest/dataset/val/no/2144.npy
# /kaggle/input/commontest/dataset/val/no/958.npy
# /kaggle/input/commontest/dataset/val/no/711.npy
# /kaggle/input/commontest/dataset/val/no/50.npy
# /kaggle/input/commontest/dataset/val/no/1018.npy
# /kaggle/input/commontest/dataset/val/no/14.npy
# /kaggle/input/commontest/dataset/val/no/1993.npy
# /kaggle/input/commontest/dataset/val/no/979.npy
# /kaggle/input/commontest/dataset/val/no/1775.npy
# /kaggle/input/commontest/dataset/val/no/1395.npy
# /kaggle/input/commontest/dataset/val/no/948.npy
# /kaggle/input/commontest/dataset/val/no/2371.npy
# /kaggle/input/commontest/dataset/val/no/1049.npy
# /kaggle/input/commontest/dataset/val/no/572.npy
# /kaggle/input/commontest/dataset/val/no/1289.npy
# /kaggle/input/commontest/dataset/val/no/1300.npy
# /kaggle/input/commontest/dataset/val/no/326.npy
# /kaggle/input/commontest/dataset/val/no/2108.npy
# /kaggle/input/commontest/dataset/val/no/1646.npy
# /kaggle/input/commontest/dataset/val/no/528.npy
# /kaggle/input/commontest/dataset/val/no/1140.npy
# /kaggle/input/commontest/dataset/val/no/148.npy
# /kaggle/input/commontest/dataset/val/no/655.npy
# /kaggle/input/commontest/dataset/val/no/2099.npy
# /kaggle/input/commontest/dataset/val/no/1459.npy
# /kaggle/input/commontest/dataset/val/no/861.npy
# /kaggle/input/commontest/dataset/val/no/1853.npy
# /kaggle/input/commontest/dataset/val/no/2261.npy
# /kaggle/input/commontest/dataset/val/no/186.npy
# /kaggle/input/commontest/dataset/val/no/1962.npy
# /kaggle/input/commontest/dataset/val/no/1809.npy
# /kaggle/input/commontest/dataset/val/no/636.npy
# /kaggle/input/commontest/dataset/val/no/1220.npy
# /kaggle/input/commontest/dataset/val/no/994.npy
# /kaggle/input/commontest/dataset/val/no/3.npy
# /kaggle/input/commontest/dataset/val/no/2016.npy
# /kaggle/input/commontest/dataset/val/no/1068.npy
# /kaggle/input/commontest/dataset/val/no/2065.npy
# /kaggle/input/commontest/dataset/val/no/2366.npy
# /kaggle/input/commontest/dataset/val/no/698.npy
# /kaggle/input/commontest/dataset/val/no/2475.npy
# /kaggle/input/commontest/dataset/val/no/1074.npy
# /kaggle/input/commontest/dataset/val/no/730.npy
# /kaggle/input/commontest/dataset/val/no/926.npy
# /kaggle/input/commontest/dataset/val/no/1739.npy
# /kaggle/input/commontest/dataset/val/no/1296.npy
# /kaggle/input/commontest/dataset/val/no/135.npy
# /kaggle/input/commontest/dataset/val/no/1945.npy
# /kaggle/input/commontest/dataset/val/no/1570.npy
# /kaggle/input/commontest/dataset/val/no/915.npy
# /kaggle/input/commontest/dataset/val/no/317.npy
# /kaggle/input/commontest/dataset/val/no/1190.npy
# /kaggle/input/commontest/dataset/val/no/341.npy
# /kaggle/input/commontest/dataset/val/no/2201.npy
# /kaggle/input/commontest/dataset/val/no/1596.npy
# /kaggle/input/commontest/dataset/val/no/966.npy
# /kaggle/input/commontest/dataset/val/no/286.npy
# /kaggle/input/commontest/dataset/val/no/520.npy
# /kaggle/input/commontest/dataset/val/no/688.npy
# /kaggle/input/commontest/dataset/val/no/2335.npy
# /kaggle/input/commontest/dataset/val/no/502.npy
# /kaggle/input/commontest/dataset/val/no/624.npy
# /kaggle/input/commontest/dataset/val/no/1682.npy
# /kaggle/input/commontest/dataset/val/no/1738.npy
# /kaggle/input/commontest/dataset/val/no/1736.npy
# /kaggle/input/commontest/dataset/val/no/1255.npy
# /kaggle/input/commontest/dataset/val/no/1252.npy
# /kaggle/input/commontest/dataset/val/no/367.npy
# /kaggle/input/commontest/dataset/val/no/2381.npy
# /kaggle/input/commontest/dataset/val/no/2364.npy
# /kaggle/input/commontest/dataset/val/no/1754.npy
# /kaggle/input/commontest/dataset/val/no/345.npy
# /kaggle/input/commontest/dataset/val/no/1307.npy
# /kaggle/input/commontest/dataset/val/no/1308.npy
# /kaggle/input/commontest/dataset/val/no/681.npy
# /kaggle/input/commontest/dataset/val/no/1790.npy
# /kaggle/input/commontest/dataset/val/no/1593.npy
# /kaggle/input/commontest/dataset/val/no/1484.npy
# /kaggle/input/commontest/dataset/val/no/1518.npy
# /kaggle/input/commontest/dataset/val/no/1554.npy
# /kaggle/input/commontest/dataset/val/no/498.npy
# /kaggle/input/commontest/dataset/val/no/1434.npy
# /kaggle/input/commontest/dataset/val/no/987.npy
# /kaggle/input/commontest/dataset/val/no/2250.npy
# /kaggle/input/commontest/dataset/val/no/1560.npy
# /kaggle/input/commontest/dataset/val/no/1160.npy
# /kaggle/input/commontest/dataset/val/no/1105.npy
# /kaggle/input/commontest/dataset/val/no/1420.npy
# /kaggle/input/commontest/dataset/val/no/1260.npy
# /kaggle/input/commontest/dataset/val/no/1787.npy
# /kaggle/input/commontest/dataset/val/no/1824.npy
# /kaggle/input/commontest/dataset/val/no/1286.npy
# /kaggle/input/commontest/dataset/val/no/1610.npy
# /kaggle/input/commontest/dataset/val/no/102.npy
# /kaggle/input/commontest/dataset/val/no/1503.npy
# /kaggle/input/commontest/dataset/val/no/899.npy
# /kaggle/input/commontest/dataset/val/no/2075.npy
# /kaggle/input/commontest/dataset/val/no/794.npy
# /kaggle/input/commontest/dataset/val/no/644.npy
# /kaggle/input/commontest/dataset/val/no/1174.npy
# /kaggle/input/commontest/dataset/val/no/293.npy
# /kaggle/input/commontest/dataset/val/no/393.npy
# /kaggle/input/commontest/dataset/val/no/2026.npy
# /kaggle/input/commontest/dataset/val/no/2107.npy
# /kaggle/input/commontest/dataset/val/no/388.npy
# /kaggle/input/commontest/dataset/val/no/2227.npy
# /kaggle/input/commontest/dataset/val/no/2002.npy
# /kaggle/input/commontest/dataset/val/no/1846.npy
# /kaggle/input/commontest/dataset/val/no/1293.npy
# /kaggle/input/commontest/dataset/val/no/1858.npy
# /kaggle/input/commontest/dataset/val/no/77.npy
# /kaggle/input/commontest/dataset/val/no/1967.npy
# /kaggle/input/commontest/dataset/val/no/1148.npy
# /kaggle/input/commontest/dataset/val/no/30.npy
# /kaggle/input/commontest/dataset/val/no/1865.npy
# /kaggle/input/commontest/dataset/val/no/1324.npy
# /kaggle/input/commontest/dataset/val/no/409.npy
# /kaggle/input/commontest/dataset/val/no/1896.npy
# /kaggle/input/commontest/dataset/val/no/1619.npy
# /kaggle/input/commontest/dataset/val/no/678.npy
# /kaggle/input/commontest/dataset/val/no/420.npy
# /kaggle/input/commontest/dataset/val/no/808.npy
# /kaggle/input/commontest/dataset/val/no/1133.npy
# /kaggle/input/commontest/dataset/val/no/322.npy
# /kaggle/input/commontest/dataset/val/no/1402.npy
# /kaggle/input/commontest/dataset/val/no/592.npy
# /kaggle/input/commontest/dataset/val/no/707.npy
# /kaggle/input/commontest/dataset/val/no/1688.npy
# /kaggle/input/commontest/dataset/val/no/24.npy
# /kaggle/input/commontest/dataset/val/no/349.npy
# /kaggle/input/commontest/dataset/val/no/883.npy
# /kaggle/input/commontest/dataset/val/no/273.npy
# /kaggle/input/commontest/dataset/val/no/1783.npy
# /kaggle/input/commontest/dataset/val/no/2456.npy
# /kaggle/input/commontest/dataset/val/no/2459.npy
# /kaggle/input/commontest/dataset/val/no/1475.npy
# /kaggle/input/commontest/dataset/val/no/251.npy
# /kaggle/input/commontest/dataset/val/no/1979.npy
# /kaggle/input/commontest/dataset/val/no/727.npy
# /kaggle/input/commontest/dataset/val/no/2018.npy
# /kaggle/input/commontest/dataset/val/no/1700.npy
# /kaggle/input/commontest/dataset/val/no/2213.npy
# /kaggle/input/commontest/dataset/val/no/1169.npy
# /kaggle/input/commontest/dataset/val/no/2089.npy
# /kaggle/input/commontest/dataset/val/no/2304.npy
# /kaggle/input/commontest/dataset/val/no/1276.npy
# /kaggle/input/commontest/dataset/val/no/2072.npy
# /kaggle/input/commontest/dataset/val/no/1692.npy
# /kaggle/input/commontest/dataset/val/no/1492.npy
# /kaggle/input/commontest/dataset/val/no/433.npy
# /kaggle/input/commontest/dataset/val/no/1697.npy
# /kaggle/input/commontest/dataset/val/no/1427.npy
# /kaggle/input/commontest/dataset/val/no/627.npy
# /kaggle/input/commontest/dataset/val/no/2044.npy
# /kaggle/input/commontest/dataset/val/no/5.npy
# /kaggle/input/commontest/dataset/val/no/70.npy
# /kaggle/input/commontest/dataset/val/no/457.npy
# /kaggle/input/commontest/dataset/val/no/1991.npy
# /kaggle/input/commontest/dataset/val/no/2439.npy
# /kaggle/input/commontest/dataset/val/no/1397.npy
# /kaggle/input/commontest/dataset/val/no/1250.npy
# /kaggle/input/commontest/dataset/val/no/1351.npy
# /kaggle/input/commontest/dataset/val/no/2376.npy
# /kaggle/input/commontest/dataset/val/no/2414.npy
# /kaggle/input/commontest/dataset/val/no/583.npy
# /kaggle/input/commontest/dataset/val/no/2465.npy
# /kaggle/input/commontest/dataset/val/no/537.npy
# /kaggle/input/commontest/dataset/val/no/418.npy
# /kaggle/input/commontest/dataset/val/no/318.npy
# /kaggle/input/commontest/dataset/val/no/444.npy
# /kaggle/input/commontest/dataset/val/no/1403.npy
# /kaggle/input/commontest/dataset/val/no/2161.npy
# /kaggle/input/commontest/dataset/val/no/2087.npy
# /kaggle/input/commontest/dataset/val/no/615.npy
# /kaggle/input/commontest/dataset/val/no/2441.npy
# /kaggle/input/commontest/dataset/val/no/761.npy
# /kaggle/input/commontest/dataset/val/no/1902.npy
# /kaggle/input/commontest/dataset/val/no/252.npy
# /kaggle/input/commontest/dataset/val/no/1735.npy
# /kaggle/input/commontest/dataset/val/no/2140.npy
# /kaggle/input/commontest/dataset/val/no/335.npy
# /kaggle/input/commontest/dataset/val/no/1507.npy
# /kaggle/input/commontest/dataset/val/no/783.npy
# /kaggle/input/commontest/dataset/val/no/2466.npy
# /kaggle/input/commontest/dataset/val/no/1803.npy
# /kaggle/input/commontest/dataset/val/no/1064.npy
# /kaggle/input/commontest/dataset/val/no/1911.npy
# /kaggle/input/commontest/dataset/val/no/1224.npy
# /kaggle/input/commontest/dataset/val/no/2405.npy
# /kaggle/input/commontest/dataset/val/no/160.npy
# /kaggle/input/commontest/dataset/val/no/1483.npy
# /kaggle/input/commontest/dataset/val/no/176.npy
# /kaggle/input/commontest/dataset/val/no/445.npy
# /kaggle/input/commontest/dataset/val/no/476.npy
# /kaggle/input/commontest/dataset/val/no/746.npy
# /kaggle/input/commontest/dataset/val/no/871.npy
# /kaggle/input/commontest/dataset/val/no/1470.npy
# /kaggle/input/commontest/dataset/val/no/1784.npy
# /kaggle/input/commontest/dataset/val/no/75.npy
# /kaggle/input/commontest/dataset/val/no/455.npy
# /kaggle/input/commontest/dataset/val/no/2406.npy
# /kaggle/input/commontest/dataset/val/no/944.npy
# /kaggle/input/commontest/dataset/val/no/849.npy
# /kaggle/input/commontest/dataset/val/no/266.npy
# /kaggle/input/commontest/dataset/val/no/1486.npy
# /kaggle/input/commontest/dataset/val/no/265.npy
# /kaggle/input/commontest/dataset/val/no/400.npy
# /kaggle/input/commontest/dataset/val/no/1152.npy
# /kaggle/input/commontest/dataset/val/no/1085.npy
# /kaggle/input/commontest/dataset/val/no/2203.npy
# /kaggle/input/commontest/dataset/val/no/705.npy
# /kaggle/input/commontest/dataset/val/no/1290.npy
# /kaggle/input/commontest/dataset/val/no/241.npy
# /kaggle/input/commontest/dataset/val/no/922.npy
# /kaggle/input/commontest/dataset/val/no/2120.npy
# /kaggle/input/commontest/dataset/val/no/2151.npy
# /kaggle/input/commontest/dataset/val/no/676.npy
# /kaggle/input/commontest/dataset/val/no/1396.npy
# /kaggle/input/commontest/dataset/val/no/239.npy
# /kaggle/input/commontest/dataset/val/no/978.npy
# /kaggle/input/commontest/dataset/val/no/1772.npy
# /kaggle/input/commontest/dataset/val/no/621.npy
# /kaggle/input/commontest/dataset/val/no/684.npy
# /kaggle/input/commontest/dataset/val/no/653.npy
# /kaggle/input/commontest/dataset/val/no/219.npy
# /kaggle/input/commontest/dataset/val/no/1042.npy
# /kaggle/input/commontest/dataset/val/no/1510.npy
# /kaggle/input/commontest/dataset/val/no/1280.npy
# /kaggle/input/commontest/dataset/val/no/1530.npy
# /kaggle/input/commontest/dataset/val/no/1350.npy
# /kaggle/input/commontest/dataset/val/no/132.npy
# /kaggle/input/commontest/dataset/val/no/1523.npy
# /kaggle/input/commontest/dataset/val/no/1781.npy
# /kaggle/input/commontest/dataset/val/no/1408.npy
# /kaggle/input/commontest/dataset/val/no/1407.npy
# /kaggle/input/commontest/dataset/val/no/2180.npy
# /kaggle/input/commontest/dataset/val/no/2023.npy
# /kaggle/input/commontest/dataset/val/no/2193.npy
# /kaggle/input/commontest/dataset/val/no/1194.npy
# /kaggle/input/commontest/dataset/val/no/2143.npy
# /kaggle/input/commontest/dataset/val/no/743.npy
# /kaggle/input/commontest/dataset/val/no/2302.npy
# /kaggle/input/commontest/dataset/val/no/156.npy
# /kaggle/input/commontest/dataset/val/no/56.npy
# /kaggle/input/commontest/dataset/val/no/1339.npy
# /kaggle/input/commontest/dataset/val/no/1760.npy
# /kaggle/input/commontest/dataset/val/no/1338.npy
# /kaggle/input/commontest/dataset/val/no/610.npy
# /kaggle/input/commontest/dataset/val/no/630.npy
# /kaggle/input/commontest/dataset/val/no/29.npy
# /kaggle/input/commontest/dataset/val/no/1741.npy
# /kaggle/input/commontest/dataset/val/no/1045.npy
# /kaggle/input/commontest/dataset/val/no/165.npy
# /kaggle/input/commontest/dataset/val/no/762.npy
# /kaggle/input/commontest/dataset/val/no/173.npy
# /kaggle/input/commontest/dataset/val/no/18.npy
# /kaggle/input/commontest/dataset/val/no/1275.npy
# /kaggle/input/commontest/dataset/val/no/666.npy
# /kaggle/input/commontest/dataset/val/no/1888.npy
# /kaggle/input/commontest/dataset/val/no/2014.npy
# /kaggle/input/commontest/dataset/val/no/1137.npy
# /kaggle/input/commontest/dataset/val/no/2103.npy
# /kaggle/input/commontest/dataset/val/no/819.npy
# /kaggle/input/commontest/dataset/val/no/297.npy
# /kaggle/input/commontest/dataset/val/no/427.npy
# /kaggle/input/commontest/dataset/val/no/2004.npy
# /kaggle/input/commontest/dataset/val/no/178.npy
# /kaggle/input/commontest/dataset/val/no/2356.npy
# /kaggle/input/commontest/dataset/val/no/854.npy
# /kaggle/input/commontest/dataset/val/no/1870.npy
# /kaggle/input/commontest/dataset/val/no/1852.npy
# /kaggle/input/commontest/dataset/val/no/561.npy
# /kaggle/input/commontest/dataset/val/no/1540.npy
# /kaggle/input/commontest/dataset/val/no/817.npy
# /kaggle/input/commontest/dataset/val/no/342.npy
# /kaggle/input/commontest/dataset/val/no/1643.npy
# /kaggle/input/commontest/dataset/val/no/2483.npy
# /kaggle/input/commontest/dataset/val/no/1713.npy
# /kaggle/input/commontest/dataset/val/no/2246.npy
# /kaggle/input/commontest/dataset/val/no/119.npy
# /kaggle/input/commontest/dataset/val/no/1360.npy
# /kaggle/input/commontest/dataset/val/no/259.npy
# /kaggle/input/commontest/dataset/val/no/458.npy
# /kaggle/input/commontest/dataset/val/no/2296.npy
# /kaggle/input/commontest/dataset/val/no/1057.npy
# /kaggle/input/commontest/dataset/val/no/1548.npy
# /kaggle/input/commontest/dataset/val/no/1867.npy
# /kaggle/input/commontest/dataset/val/no/270.npy
# /kaggle/input/commontest/dataset/val/no/2210.npy
# /kaggle/input/commontest/dataset/val/no/275.npy
# /kaggle/input/commontest/dataset/val/no/1640.npy
# /kaggle/input/commontest/dataset/val/no/221.npy
# /kaggle/input/commontest/dataset/val/no/2010.npy
# /kaggle/input/commontest/dataset/val/no/598.npy
# /kaggle/input/commontest/dataset/val/no/443.npy
# /kaggle/input/commontest/dataset/val/no/215.npy
# /kaggle/input/commontest/dataset/val/no/2079.npy
# /kaggle/input/commontest/dataset/val/no/1704.npy
# /kaggle/input/commontest/dataset/val/no/620.npy
# /kaggle/input/commontest/dataset/val/no/927.npy
# /kaggle/input/commontest/dataset/val/no/1161.npy
# /kaggle/input/commontest/dataset/val/no/94.npy
# /kaggle/input/commontest/dataset/val/no/1159.npy
# /kaggle/input/commontest/dataset/val/no/674.npy
# /kaggle/input/commontest/dataset/val/no/1586.npy
# /kaggle/input/commontest/dataset/val/no/2343.npy
# /kaggle/input/commontest/dataset/val/no/276.npy
# /kaggle/input/commontest/dataset/val/no/96.npy
# /kaggle/input/commontest/dataset/val/no/299.npy
# /kaggle/input/commontest/dataset/val/no/2007.npy
# /kaggle/input/commontest/dataset/val/no/2066.npy
# /kaggle/input/commontest/dataset/val/no/423.npy
# /kaggle/input/commontest/dataset/val/no/462.npy
# /kaggle/input/commontest/dataset/val/no/115.npy
# /kaggle/input/commontest/dataset/val/no/2078.npy
# /kaggle/input/commontest/dataset/val/no/1953.npy
# /kaggle/input/commontest/dataset/val/no/1118.npy
# /kaggle/input/commontest/dataset/val/no/1928.npy
# /kaggle/input/commontest/dataset/val/no/2428.npy
# /kaggle/input/commontest/dataset/val/no/1842.npy
# /kaggle/input/commontest/dataset/val/no/337.npy
# /kaggle/input/commontest/dataset/val/no/446.npy
# /kaggle/input/commontest/dataset/val/no/2312.npy
# /kaggle/input/commontest/dataset/val/no/1438.npy
# /kaggle/input/commontest/dataset/val/no/386.npy
# /kaggle/input/commontest/dataset/val/no/1939.npy
# /kaggle/input/commontest/dataset/val/no/1617.npy
# /kaggle/input/commontest/dataset/val/no/22.npy
# /kaggle/input/commontest/dataset/val/no/238.npy
# /kaggle/input/commontest/dataset/val/no/2282.npy
# /kaggle/input/commontest/dataset/val/no/774.npy
# /kaggle/input/commontest/dataset/val/no/1496.npy
# /kaggle/input/commontest/dataset/val/no/672.npy
# /kaggle/input/commontest/dataset/val/no/88.npy
# /kaggle/input/commontest/dataset/val/no/1437.npy
# /kaggle/input/commontest/dataset/val/no/302.npy
# /kaggle/input/commontest/dataset/val/no/190.npy
# /kaggle/input/commontest/dataset/val/no/2100.npy
# /kaggle/input/commontest/dataset/val/no/469.npy
# /kaggle/input/commontest/dataset/val/no/356.npy
# /kaggle/input/commontest/dataset/val/no/2101.npy
# /kaggle/input/commontest/dataset/val/no/1002.npy
# /kaggle/input/commontest/dataset/val/no/521.npy
# /kaggle/input/commontest/dataset/val/no/1800.npy
# /kaggle/input/commontest/dataset/val/no/2253.npy
# /kaggle/input/commontest/dataset/val/no/460.npy
# /kaggle/input/commontest/dataset/val/no/1325.npy
# /kaggle/input/commontest/dataset/val/no/539.npy
# /kaggle/input/commontest/dataset/val/no/406.npy
# /kaggle/input/commontest/dataset/val/no/722.npy
# /kaggle/input/commontest/dataset/val/no/351.npy
# /kaggle/input/commontest/dataset/val/no/1651.npy
# /kaggle/input/commontest/dataset/val/no/495.npy
# /kaggle/input/commontest/dataset/val/no/999.npy
# /kaggle/input/commontest/dataset/val/no/1944.npy
# /kaggle/input/commontest/dataset/val/no/2058.npy
# /kaggle/input/commontest/dataset/val/no/2419.npy
# /kaggle/input/commontest/dataset/val/no/2344.npy
# /kaggle/input/commontest/dataset/val/no/2360.npy
# /kaggle/input/commontest/dataset/val/no/694.npy
# /kaggle/input/commontest/dataset/val/no/207.npy
# /kaggle/input/commontest/dataset/val/no/1675.npy
# /kaggle/input/commontest/dataset/val/no/1346.npy
# /kaggle/input/commontest/dataset/val/no/2055.npy
# /kaggle/input/commontest/dataset/val/no/1217.npy
# /kaggle/input/commontest/dataset/val/no/2396.npy
# /kaggle/input/commontest/dataset/val/no/2382.npy
# /kaggle/input/commontest/dataset/val/no/1686.npy
# /kaggle/input/commontest/dataset/val/no/1891.npy
# /kaggle/input/commontest/dataset/val/no/358.npy
# /kaggle/input/commontest/dataset/val/no/1750.npy
# /kaggle/input/commontest/dataset/val/no/1536.npy
# /kaggle/input/commontest/dataset/val/no/97.npy
# /kaggle/input/commontest/dataset/val/no/823.npy
# /kaggle/input/commontest/dataset/val/no/1073.npy
# /kaggle/input/commontest/dataset/val/no/1892.npy
# /kaggle/input/commontest/dataset/val/no/2474.npy
# /kaggle/input/commontest/dataset/val/no/852.npy
# /kaggle/input/commontest/dataset/val/no/370.npy
# /kaggle/input/commontest/dataset/val/no/2311.npy
# /kaggle/input/commontest/dataset/val/no/809.npy
# /kaggle/input/commontest/dataset/val/no/2494.npy
# /kaggle/input/commontest/dataset/val/no/2469.npy
# /kaggle/input/commontest/dataset/val/no/217.npy
# /kaggle/input/commontest/dataset/val/no/1917.npy
# /kaggle/input/commontest/dataset/val/no/2375.npy
# /kaggle/input/commontest/dataset/val/no/339.npy
# /kaggle/input/commontest/dataset/val/no/17.npy
# /kaggle/input/commontest/dataset/val/no/1062.npy
# /kaggle/input/commontest/dataset/val/no/497.npy
# /kaggle/input/commontest/dataset/val/no/1746.npy
# /kaggle/input/commontest/dataset/val/no/44.npy
# /kaggle/input/commontest/dataset/val/no/430.npy
# /kaggle/input/commontest/dataset/val/no/254.npy
# /kaggle/input/commontest/dataset/val/no/2492.npy
# /kaggle/input/commontest/dataset/val/no/1668.npy
# /kaggle/input/commontest/dataset/val/no/2427.npy
# /kaggle/input/commontest/dataset/val/no/1584.npy
# /kaggle/input/commontest/dataset/val/no/1162.npy
# /kaggle/input/commontest/dataset/val/no/1909.npy
# /kaggle/input/commontest/dataset/val/no/635.npy
# /kaggle/input/commontest/dataset/val/no/1899.npy
# /kaggle/input/commontest/dataset/val/no/1131.npy
# /kaggle/input/commontest/dataset/val/no/1310.npy
# /kaggle/input/commontest/dataset/val/no/1094.npy
# /kaggle/input/commontest/dataset/val/no/1288.npy
# /kaggle/input/commontest/dataset/val/no/1638.npy
# /kaggle/input/commontest/dataset/val/no/1222.npy
# /kaggle/input/commontest/dataset/val/no/657.npy
# /kaggle/input/commontest/dataset/val/no/1478.npy
# /kaggle/input/commontest/dataset/val/no/1150.npy
# /kaggle/input/commontest/dataset/val/no/2148.npy
# /kaggle/input/commontest/dataset/val/no/1696.npy
# /kaggle/input/commontest/dataset/val/no/1695.npy
# /kaggle/input/commontest/dataset/val/no/2.npy
# /kaggle/input/commontest/dataset/val/no/288.npy
# /kaggle/input/commontest/dataset/val/no/26.npy
# /kaggle/input/commontest/dataset/val/no/793.npy
# /kaggle/input/commontest/dataset/val/no/931.npy
# /kaggle/input/commontest/dataset/val/no/1413.npy
# /kaggle/input/commontest/dataset/val/no/83.npy
# /kaggle/input/commontest/dataset/val/no/1863.npy
# /kaggle/input/commontest/dataset/val/no/1869.npy
# /kaggle/input/commontest/dataset/val/no/436.npy
# /kaggle/input/commontest/dataset/val/no/1390.npy
# /kaggle/input/commontest/dataset/val/no/813.npy
# /kaggle/input/commontest/dataset/val/no/183.npy
# /kaggle/input/commontest/dataset/val/no/1471.npy
# /kaggle/input/commontest/dataset/val/no/670.npy
# /kaggle/input/commontest/dataset/val/no/643.npy
# /kaggle/input/commontest/dataset/val/no/1807.npy
# /kaggle/input/commontest/dataset/val/no/2358.npy
# /kaggle/input/commontest/dataset/val/no/1378.npy
# /kaggle/input/commontest/dataset/val/no/1641.npy
# /kaggle/input/commontest/dataset/val/no/1673.npy
# /kaggle/input/commontest/dataset/val/no/2134.npy
# /kaggle/input/commontest/dataset/val/no/896.npy
# /kaggle/input/commontest/dataset/val/no/1983.npy
# /kaggle/input/commontest/dataset/val/no/2046.npy
# /kaggle/input/commontest/dataset/val/no/932.npy
# /kaggle/input/commontest/dataset/val/no/1405.npy
# /kaggle/input/commontest/dataset/val/no/2294.npy
# /kaggle/input/commontest/dataset/val/no/236.npy
# /kaggle/input/commontest/dataset/val/no/1811.npy
# /kaggle/input/commontest/dataset/val/no/2260.npy
# /kaggle/input/commontest/dataset/val/no/36.npy
# /kaggle/input/commontest/dataset/val/no/1856.npy
# /kaggle/input/commontest/dataset/val/no/1773.npy
# /kaggle/input/commontest/dataset/val/no/1020.npy
# /kaggle/input/commontest/dataset/val/no/1139.npy
# /kaggle/input/commontest/dataset/val/no/1615.npy
# /kaggle/input/commontest/dataset/val/no/1061.npy
# /kaggle/input/commontest/dataset/val/no/1052.npy
# /kaggle/input/commontest/dataset/val/no/1091.npy
# /kaggle/input/commontest/dataset/val/no/1850.npy
# /kaggle/input/commontest/dataset/val/no/2402.npy
# /kaggle/input/commontest/dataset/val/no/2409.npy
# /kaggle/input/commontest/dataset/val/no/89.npy
# /kaggle/input/commontest/dataset/val/no/802.npy
# /kaggle/input/commontest/dataset/val/no/977.npy
# /kaggle/input/commontest/dataset/val/no/2400.npy
# /kaggle/input/commontest/dataset/val/no/748.npy
# /kaggle/input/commontest/dataset/val/no/2277.npy
# /kaggle/input/commontest/dataset/val/no/1618.npy
# /kaggle/input/commontest/dataset/val/no/1457.npy
# /kaggle/input/commontest/dataset/val/no/2499.npy
# /kaggle/input/commontest/dataset/val/no/133.npy
# /kaggle/input/commontest/dataset/val/no/1751.npy
# /kaggle/input/commontest/dataset/val/no/921.npy
# /kaggle/input/commontest/dataset/val/no/303.npy
# /kaggle/input/commontest/dataset/val/no/2332.npy
# /kaggle/input/commontest/dataset/val/no/1009.npy
# /kaggle/input/commontest/dataset/val/no/1831.npy
# /kaggle/input/commontest/dataset/val/no/1609.npy
# /kaggle/input/commontest/dataset/val/no/1292.npy
# /kaggle/input/commontest/dataset/val/no/424.npy
# /kaggle/input/commontest/dataset/val/no/2478.npy
# /kaggle/input/commontest/dataset/val/no/2339.npy
# /kaggle/input/commontest/dataset/val/no/230.npy
# /kaggle/input/commontest/dataset/val/no/1604.npy
# /kaggle/input/commontest/dataset/val/no/1181.npy
# /kaggle/input/commontest/dataset/val/no/1374.npy
# /kaggle/input/commontest/dataset/val/no/567.npy
# /kaggle/input/commontest/dataset/val/no/924.npy
# /kaggle/input/commontest/dataset/val/no/361.npy
# /kaggle/input/commontest/dataset/val/no/2043.npy
# /kaggle/input/commontest/dataset/val/no/171.npy
# /kaggle/input/commontest/dataset/val/no/1388.npy
# /kaggle/input/commontest/dataset/val/no/2031.npy
# /kaggle/input/commontest/dataset/val/no/1365.npy
# /kaggle/input/commontest/dataset/val/no/744.npy
# /kaggle/input/commontest/dataset/val/no/973.npy
# /kaggle/input/commontest/dataset/val/no/2433.npy
# /kaggle/input/commontest/dataset/val/no/1731.npy
# /kaggle/input/commontest/dataset/val/no/1886.npy
# /kaggle/input/commontest/dataset/val/no/1575.npy
# /kaggle/input/commontest/dataset/val/no/2090.npy
# /kaggle/input/commontest/dataset/val/no/1474.npy
# /kaggle/input/commontest/dataset/val/no/2325.npy
# /kaggle/input/commontest/dataset/val/no/991.npy
# /kaggle/input/commontest/dataset/val/no/2484.npy
# /kaggle/input/commontest/dataset/val/no/1110.npy
# /kaggle/input/commontest/dataset/val/no/1964.npy
# /kaggle/input/commontest/dataset/val/no/1512.npy
# /kaggle/input/commontest/dataset/val/no/920.npy
# /kaggle/input/commontest/dataset/val/no/2027.npy
# /kaggle/input/commontest/dataset/val/no/1774.npy
# /kaggle/input/commontest/dataset/val/no/231.npy
# /kaggle/input/commontest/dataset/val/no/1777.npy
# /kaggle/input/commontest/dataset/val/no/459.npy
# /kaggle/input/commontest/dataset/val/no/1264.npy
# /kaggle/input/commontest/dataset/val/no/2461.npy
# /kaggle/input/commontest/dataset/val/no/2345.npy
# /kaggle/input/commontest/dataset/val/no/1343.npy
# /kaggle/input/commontest/dataset/val/no/1228.npy
# /kaggle/input/commontest/dataset/val/no/197.npy
# /kaggle/input/commontest/dataset/val/no/2135.npy
# /kaggle/input/commontest/dataset/val/no/2377.npy
# /kaggle/input/commontest/dataset/val/no/835.npy
# /kaggle/input/commontest/dataset/val/no/85.npy
# /kaggle/input/commontest/dataset/val/no/1798.npy
# /kaggle/input/commontest/dataset/val/no/1498.npy
# /kaggle/input/commontest/dataset/val/no/2437.npy
# /kaggle/input/commontest/dataset/val/no/313.npy
# /kaggle/input/commontest/dataset/val/no/1764.npy
# /kaggle/input/commontest/dataset/val/no/1522.npy
# /kaggle/input/commontest/dataset/val/no/2235.npy
# /kaggle/input/commontest/dataset/val/no/2074.npy
# /kaggle/input/commontest/dataset/val/no/882.npy
# /kaggle/input/commontest/dataset/val/no/595.npy
# /kaggle/input/commontest/dataset/val/no/300.npy
# /kaggle/input/commontest/dataset/val/no/2372.npy
# /kaggle/input/commontest/dataset/val/no/1186.npy
# /kaggle/input/commontest/dataset/val/no/1974.npy
# /kaggle/input/commontest/dataset/val/no/2229.npy
# /kaggle/input/commontest/dataset/val/no/917.npy
# /kaggle/input/commontest/dataset/val/no/2147.npy
# /kaggle/input/commontest/dataset/val/no/554.npy
# /kaggle/input/commontest/dataset/val/no/504.npy
# /kaggle/input/commontest/dataset/val/no/395.npy
# /kaggle/input/commontest/dataset/val/no/1090.npy
# /kaggle/input/commontest/dataset/val/no/27.npy
# /kaggle/input/commontest/dataset/val/no/2310.npy
# /kaggle/input/commontest/dataset/val/no/4.npy
# /kaggle/input/commontest/dataset/val/no/1805.npy
# /kaggle/input/commontest/dataset/val/no/1246.npy
# /kaggle/input/commontest/dataset/val/no/2185.npy
# /kaggle/input/commontest/dataset/val/no/928.npy
# /kaggle/input/commontest/dataset/val/no/625.npy
# /kaggle/input/commontest/dataset/val/no/2001.npy
# /kaggle/input/commontest/dataset/val/no/1679.npy
# /kaggle/input/commontest/dataset/val/no/769.npy
# /kaggle/input/commontest/dataset/val/no/1901.npy
# /kaggle/input/commontest/dataset/val/no/9.npy
# /kaggle/input/commontest/dataset/val/no/828.npy
# /kaggle/input/commontest/dataset/val/no/1860.npy
# /kaggle/input/commontest/dataset/val/no/37.npy
# /kaggle/input/commontest/dataset/val/no/289.npy
# /kaggle/input/commontest/dataset/val/no/2186.npy
# /kaggle/input/commontest/dataset/val/no/227.npy
# /kaggle/input/commontest/dataset/val/no/118.npy
# /kaggle/input/commontest/dataset/val/no/321.npy
# /kaggle/input/commontest/dataset/val/no/1501.npy
# /kaggle/input/commontest/dataset/val/no/1549.npy
# /kaggle/input/commontest/dataset/val/no/1104.npy
# /kaggle/input/commontest/dataset/val/no/602.npy
# /kaggle/input/commontest/dataset/val/no/587.npy
# /kaggle/input/commontest/dataset/val/no/249.npy
# /kaggle/input/commontest/dataset/val/no/76.npy
# /kaggle/input/commontest/dataset/val/no/905.npy
# /kaggle/input/commontest/dataset/val/no/1621.npy
# /kaggle/input/commontest/dataset/val/no/2267.npy
# /kaggle/input/commontest/dataset/val/no/2287.npy
# /kaggle/input/commontest/dataset/val/no/1611.npy
# /kaggle/input/commontest/dataset/val/no/1727.npy
# /kaggle/input/commontest/dataset/val/no/1508.npy
# /kaggle/input/commontest/dataset/val/no/525.npy
# /kaggle/input/commontest/dataset/val/no/791.npy
# /kaggle/input/commontest/dataset/val/no/1528.npy
# /kaggle/input/commontest/dataset/val/no/2169.npy
# /kaggle/input/commontest/dataset/val/no/1629.npy
# /kaggle/input/commontest/dataset/val/no/1546.npy
# /kaggle/input/commontest/dataset/val/no/770.npy
# /kaggle/input/commontest/dataset/val/no/2069.npy
# /kaggle/input/commontest/dataset/val/no/1632.npy
# /kaggle/input/commontest/dataset/val/no/546.npy
# /kaggle/input/commontest/dataset/val/no/512.npy
# /kaggle/input/commontest/dataset/val/no/1274.npy
# /kaggle/input/commontest/dataset/val/no/632.npy
# /kaggle/input/commontest/dataset/val/no/1900.npy
# /kaggle/input/commontest/dataset/val/no/2214.npy
# /kaggle/input/commontest/dataset/val/no/1112.npy
# /kaggle/input/commontest/dataset/val/no/1933.npy
# /kaggle/input/commontest/dataset/val/no/2425.npy
# /kaggle/input/commontest/dataset/val/no/1003.npy
# /kaggle/input/commontest/dataset/val/no/1066.npy
# /kaggle/input/commontest/dataset/val/no/1302.npy
# /kaggle/input/commontest/dataset/val/no/1630.npy
# /kaggle/input/commontest/dataset/val/no/360.npy
# /kaggle/input/commontest/dataset/val/no/1921.npy
# /kaggle/input/commontest/dataset/val/no/1664.npy
# /kaggle/input/commontest/dataset/val/no/468.npy
# /kaggle/input/commontest/dataset/val/no/1465.npy
# /kaggle/input/commontest/dataset/val/no/1529.npy
# /kaggle/input/commontest/dataset/val/no/717.npy
# /kaggle/input/commontest/dataset/val/no/658.npy
# /kaggle/input/commontest/dataset/val/no/1320.npy
# /kaggle/input/commontest/dataset/val/no/213.npy
# /kaggle/input/commontest/dataset/val/no/1368.npy
# /kaggle/input/commontest/dataset/val/no/939.npy
# /kaggle/input/commontest/dataset/val/no/237.npy
# /kaggle/input/commontest/dataset/val/no/155.npy
# /kaggle/input/commontest/dataset/val/no/1331.npy
# /kaggle/input/commontest/dataset/val/no/1382.npy
# /kaggle/input/commontest/dataset/val/no/742.npy
# /kaggle/input/commontest/dataset/val/no/1871.npy
# /kaggle/input/commontest/dataset/val/no/1658.npy
# /kaggle/input/commontest/dataset/val/no/120.npy
# /kaggle/input/commontest/dataset/val/no/1725.npy
# /kaggle/input/commontest/dataset/val/no/1924.npy
# /kaggle/input/commontest/dataset/val/no/2190.npy
# /kaggle/input/commontest/dataset/val/no/128.npy
# /kaggle/input/commontest/dataset/val/no/1172.npy
# /kaggle/input/commontest/dataset/val/no/1450.npy
# /kaggle/input/commontest/dataset/val/no/58.npy
# /kaggle/input/commontest/dataset/val/no/1782.npy
# /kaggle/input/commontest/dataset/val/no/260.npy
# /kaggle/input/commontest/dataset/val/no/90.npy
# /kaggle/input/commontest/dataset/val/no/2150.npy
# /kaggle/input/commontest/dataset/val/no/997.npy
# /kaggle/input/commontest/dataset/val/no/467.npy
# /kaggle/input/commontest/dataset/val/no/383.npy
# /kaggle/input/commontest/dataset/val/no/1367.npy
# /kaggle/input/commontest/dataset/val/no/1866.npy
# /kaggle/input/commontest/dataset/val/no/1833.npy
# /kaggle/input/commontest/dataset/val/no/2205.npy
# /kaggle/input/commontest/dataset/val/no/938.npy
# /kaggle/input/commontest/dataset/val/no/2061.npy
# /kaggle/input/commontest/dataset/val/no/2289.npy
# /kaggle/input/commontest/dataset/val/no/975.npy
# /kaggle/input/commontest/dataset/val/no/2392.npy
# /kaggle/input/commontest/dataset/val/no/1149.npy
# /kaggle/input/commontest/dataset/val/no/820.npy
# /kaggle/input/commontest/dataset/val/no/1185.npy
# /kaggle/input/commontest/dataset/val/no/637.npy
# /kaggle/input/commontest/dataset/val/no/2245.npy
# /kaggle/input/commontest/dataset/val/no/71.npy
# /kaggle/input/commontest/dataset/val/no/2365.npy
# /kaggle/input/commontest/dataset/val/no/2422.npy
# /kaggle/input/commontest/dataset/val/no/2117.npy
# /kaggle/input/commontest/dataset/val/no/1872.npy
# /kaggle/input/commontest/dataset/val/no/1215.npy
# ...
# /kaggle/input/commontest/dataset/train/sphere/6763.npy
# /kaggle/input/commontest/dataset/train/sphere/2750.npy
# /kaggle/input/commontest/dataset/train/sphere/591.npy
# /kaggle/input/commontest/dataset/train/sphere/9381.npy
# /kaggle/input/commontest/dataset/train/sphere/1971.npy
# /kaggle/input/commontest/dataset/train/sphere/8931.npy
# /kaggle/input/commontest/dataset/train/sphere/5995.npy
# /kaggle/input/commontest/dataset/train/sphere/7947.npy
# /kaggle/input/commontest/dataset/train/sphere/6752.npy
# /kaggle/input/commontest/dataset/train/sphere/3658.npy
# /kaggle/input/commontest/dataset/train/sphere/720.npy
# /kaggle/input/commontest/dataset/train/sphere/5373.npy
# /kaggle/input/commontest/dataset/train/sphere/7208.npy
# /kaggle/input/commontest/dataset/train/sphere/5551.npy
# /kaggle/input/commontest/dataset/train/sphere/8752.npy
# /kaggle/input/commontest/dataset/train/sphere/1716.npy
# /kaggle/input/commontest/dataset/train/sphere/8065.npy
# /kaggle/input/commontest/dataset/train/sphere/4942.npy
# /kaggle/input/commontest/dataset/train/sphere/6301.npy
# /kaggle/input/commontest/dataset/train/sphere/7376.npy
# /kaggle/input/commontest/dataset/train/sphere/6299.npy
# /kaggle/input/commontest/dataset/train/sphere/6220.npy
# /kaggle/input/commontest/dataset/train/sphere/2854.npy
# /kaggle/input/commontest/dataset/train/sphere/2348.npy
# /kaggle/input/commontest/dataset/train/sphere/7136.npy
# /kaggle/input/commontest/dataset/train/sphere/8509.npy
# /kaggle/input/commontest/dataset/train/sphere/7402.npy
# /kaggle/input/commontest/dataset/train/sphere/4503.npy
# /kaggle/input/commontest/dataset/train/sphere/3185.npy
# /kaggle/input/commontest/dataset/train/sphere/8153.npy
# /kaggle/input/commontest/dataset/train/sphere/7445.npy
# /kaggle/input/commontest/dataset/train/sphere/5366.npy
# /kaggle/input/commontest/dataset/train/sphere/5948.npy
# /kaggle/input/commontest/dataset/train/sphere/4132.npy
# /kaggle/input/commontest/dataset/train/sphere/7131.npy
# /kaggle/input/commontest/dataset/train/sphere/4810.npy
# /kaggle/input/commontest/dataset/train/sphere/8075.npy
# /kaggle/input/commontest/dataset/train/sphere/577.npy
# /kaggle/input/commontest/dataset/train/sphere/8143.npy
# /kaggle/input/commontest/dataset/train/sphere/7822.npy
# /kaggle/input/commontest/dataset/train/sphere/9225.npy
# /kaggle/input/commontest/dataset/train/sphere/9538.npy
# /kaggle/input/commontest/dataset/train/sphere/2131.npy
# /kaggle/input/commontest/dataset/train/sphere/955.npy
# /kaggle/input/commontest/dataset/train/sphere/9235.npy
# /kaggle/input/commontest/dataset/train/sphere/3644.npy
# /kaggle/input/commontest/dataset/train/sphere/6098.npy
# /kaggle/input/commontest/dataset/train/sphere/1493.npy
# /kaggle/input/commontest/dataset/train/sphere/1779.npy
# /kaggle/input/commontest/dataset/train/sphere/3915.npy
# /kaggle/input/commontest/dataset/train/sphere/1605.npy
# /kaggle/input/commontest/dataset/train/sphere/2511.npy
# /kaggle/input/commontest/dataset/train/sphere/9053.npy
# /kaggle/input/commontest/dataset/train/sphere/623.npy
# /kaggle/input/commontest/dataset/train/sphere/6286.npy
# /kaggle/input/commontest/dataset/train/sphere/9953.npy
# /kaggle/input/commontest/dataset/train/sphere/9648.npy
# /kaggle/input/commontest/dataset/train/sphere/5977.npy
# /kaggle/input/commontest/dataset/train/sphere/1491.npy
# /kaggle/input/commontest/dataset/train/sphere/4001.npy
# /kaggle/input/commontest/dataset/train/sphere/4757.npy
# /kaggle/input/commontest/dataset/train/sphere/8655.npy
# /kaggle/input/commontest/dataset/train/sphere/8903.npy
# /kaggle/input/commontest/dataset/train/sphere/4026.npy
# /kaggle/input/commontest/dataset/train/sphere/4449.npy
# /kaggle/input/commontest/dataset/train/sphere/8974.npy
# /kaggle/input/commontest/dataset/train/sphere/6036.npy
# /kaggle/input/commontest/dataset/train/sphere/2309.npy
# /kaggle/input/commontest/dataset/train/sphere/2032.npy
# /kaggle/input/commontest/dataset/train/sphere/7828.npy
# /kaggle/input/commontest/dataset/train/sphere/2012.npy
# /kaggle/input/commontest/dataset/train/sphere/3757.npy
# /kaggle/input/commontest/dataset/train/sphere/309.npy
# /kaggle/input/commontest/dataset/train/sphere/3957.npy
# /kaggle/input/commontest/dataset/train/sphere/4097.npy
# /kaggle/input/commontest/dataset/train/sphere/9831.npy
# /kaggle/input/commontest/dataset/train/sphere/8906.npy
# /kaggle/input/commontest/dataset/train/sphere/1145.npy
# /kaggle/input/commontest/dataset/train/sphere/6435.npy
# /kaggle/input/commontest/dataset/train/sphere/2336.npy
# /kaggle/input/commontest/dataset/train/sphere/5419.npy
# /kaggle/input/commontest/dataset/train/sphere/7569.npy
# /kaggle/input/commontest/dataset/train/sphere/4799.npy
# /kaggle/input/commontest/dataset/train/sphere/5694.npy
# /kaggle/input/commontest/dataset/train/sphere/2735.npy
# /kaggle/input/commontest/dataset/train/sphere/4756.npy
# /kaggle/input/commontest/dataset/train/sphere/1409.npy
# /kaggle/input/commontest/dataset/train/sphere/9180.npy
# /kaggle/input/commontest/dataset/train/sphere/8784.npy
# /kaggle/input/commontest/dataset/train/sphere/6474.npy
# /kaggle/input/commontest/dataset/train/sphere/4576.npy
# /kaggle/input/commontest/dataset/train/sphere/8595.npy
# /kaggle/input/commontest/dataset/train/sphere/3290.npy
# /kaggle/input/commontest/dataset/train/sphere/8748.npy
# /kaggle/input/commontest/dataset/train/sphere/1672.npy
# /kaggle/input/commontest/dataset/train/sphere/800.npy
# /kaggle/input/commontest/dataset/train/sphere/564.npy
# /kaggle/input/commontest/dataset/train/sphere/1922.npy
# /kaggle/input/commontest/dataset/train/sphere/2168.npy
# /kaggle/input/commontest/dataset/train/sphere/1997.npy
# /kaggle/input/commontest/dataset/train/sphere/484.npy
# /kaggle/input/commontest/dataset/train/sphere/6520.npy
# /kaggle/input/commontest/dataset/train/sphere/2950.npy
# /kaggle/input/commontest/dataset/train/sphere/3924.npy
# /kaggle/input/commontest/dataset/train/sphere/3053.npy
# /kaggle/input/commontest/dataset/train/sphere/6963.npy
# /kaggle/input/commontest/dataset/train/sphere/216.npy
# /kaggle/input/commontest/dataset/train/sphere/4478.npy
# /kaggle/input/commontest/dataset/train/sphere/501.npy
# /kaggle/input/commontest/dataset/train/sphere/1142.npy
# /kaggle/input/commontest/dataset/train/sphere/3471.npy
# /kaggle/input/commontest/dataset/train/sphere/4281.npy
# /kaggle/input/commontest/dataset/train/sphere/9888.npy
# /kaggle/input/commontest/dataset/train/sphere/2614.npy
# /kaggle/input/commontest/dataset/train/sphere/3375.npy
# /kaggle/input/commontest/dataset/train/sphere/6341.npy
# /kaggle/input/commontest/dataset/train/sphere/4639.npy
# /kaggle/input/commontest/dataset/train/sphere/1043.npy
# /kaggle/input/commontest/dataset/train/sphere/4271.npy
# /kaggle/input/commontest/dataset/train/sphere/3301.npy
# /kaggle/input/commontest/dataset/train/sphere/5241.npy
# /kaggle/input/commontest/dataset/train/sphere/3645.npy
# /kaggle/input/commontest/dataset/train/sphere/2905.npy
# /kaggle/input/commontest/dataset/train/sphere/4869.npy
# /kaggle/input/commontest/dataset/train/sphere/6125.npy
# /kaggle/input/commontest/dataset/train/sphere/2909.npy
# /kaggle/input/commontest/dataset/train/sphere/2073.npy
# /kaggle/input/commontest/dataset/train/sphere/5493.npy
# /kaggle/input/commontest/dataset/train/sphere/7543.npy
# /kaggle/input/commontest/dataset/train/sphere/1796.npy
# /kaggle/input/commontest/dataset/train/sphere/8614.npy
# /kaggle/input/commontest/dataset/train/sphere/3283.npy
# /kaggle/input/commontest/dataset/train/sphere/3553.npy
# /kaggle/input/commontest/dataset/train/sphere/2520.npy
# /kaggle/input/commontest/dataset/train/sphere/6442.npy
# /kaggle/input/commontest/dataset/train/sphere/8193.npy
# /kaggle/input/commontest/dataset/train/sphere/7293.npy
# /kaggle/input/commontest/dataset/train/sphere/9183.npy
# /kaggle/input/commontest/dataset/train/sphere/1098.npy
# /kaggle/input/commontest/dataset/train/sphere/5772.npy
# /kaggle/input/commontest/dataset/train/sphere/8832.npy
# /kaggle/input/commontest/dataset/train/sphere/9117.npy
# /kaggle/input/commontest/dataset/train/sphere/7791.npy
# /kaggle/input/commontest/dataset/train/sphere/4820.npy
# /kaggle/input/commontest/dataset/train/sphere/6159.npy
# /kaggle/input/commontest/dataset/train/sphere/7979.npy
# /kaggle/input/commontest/dataset/train/sphere/9190.npy
# /kaggle/input/commontest/dataset/train/sphere/125.npy
# /kaggle/input/commontest/dataset/train/sphere/7693.npy
# /kaggle/input/commontest/dataset/train/sphere/4625.npy
# /kaggle/input/commontest/dataset/train/sphere/6769.npy
# /kaggle/input/commontest/dataset/train/sphere/2886.npy
# /kaggle/input/commontest/dataset/train/sphere/5359.npy
# /kaggle/input/commontest/dataset/train/sphere/6397.npy
# /kaggle/input/commontest/dataset/train/sphere/825.npy
# /kaggle/input/commontest/dataset/train/sphere/1693.npy
# /kaggle/input/commontest/dataset/train/sphere/1823.npy
# /kaggle/input/commontest/dataset/train/sphere/7258.npy
# /kaggle/input/commontest/dataset/train/sphere/639.npy
# /kaggle/input/commontest/dataset/train/sphere/4092.npy
# /kaggle/input/commontest/dataset/train/sphere/7477.npy
# /kaggle/input/commontest/dataset/train/sphere/7780.npy
# /kaggle/input/commontest/dataset/train/sphere/2129.npy
# /kaggle/input/commontest/dataset/train/sphere/6661.npy
# /kaggle/input/commontest/dataset/train/sphere/559.npy
# /kaggle/input/commontest/dataset/train/sphere/9325.npy
# /kaggle/input/commontest/dataset/train/sphere/1743.npy
# /kaggle/input/commontest/dataset/train/sphere/9417.npy
# /kaggle/input/commontest/dataset/train/sphere/5244.npy
# /kaggle/input/commontest/dataset/train/sphere/6578.npy
# /kaggle/input/commontest/dataset/train/sphere/6935.npy
# /kaggle/input/commontest/dataset/train/sphere/3404.npy
# /kaggle/input/commontest/dataset/train/sphere/4704.npy
# /kaggle/input/commontest/dataset/train/sphere/2622.npy
# /kaggle/input/commontest/dataset/train/sphere/9724.npy
# /kaggle/input/commontest/dataset/train/sphere/4134.npy
# /kaggle/input/commontest/dataset/train/sphere/8571.npy
# /kaggle/input/commontest/dataset/train/sphere/3475.npy
# /kaggle/input/commontest/dataset/train/sphere/3148.npy
# /kaggle/input/commontest/dataset/train/sphere/1915.npy
# /kaggle/input/commontest/dataset/train/sphere/1183.npy
# /kaggle/input/commontest/dataset/train/sphere/1631.npy
# /kaggle/input/commontest/dataset/train/sphere/5324.npy
# /kaggle/input/commontest/dataset/train/sphere/7084.npy
# /kaggle/input/commontest/dataset/train/sphere/4250.npy
# /kaggle/input/commontest/dataset/train/sphere/9327.npy
# /kaggle/input/commontest/dataset/train/sphere/6160.npy
# /kaggle/input/commontest/dataset/train/sphere/3450.npy
# /kaggle/input/commontest/dataset/train/sphere/5464.npy
# /kaggle/input/commontest/dataset/train/sphere/4057.npy
# /kaggle/input/commontest/dataset/train/sphere/6660.npy
# /kaggle/input/commontest/dataset/train/sphere/5023.npy
# /kaggle/input/commontest/dataset/train/sphere/1887.npy
# /kaggle/input/commontest/dataset/train/sphere/2157.npy
# /kaggle/input/commontest/dataset/train/sphere/2234.npy
# /kaggle/input/commontest/dataset/train/sphere/1309.npy
# /kaggle/input/commontest/dataset/train/sphere/1219.npy
# /kaggle/input/commontest/dataset/train/sphere/8677.npy
# /kaggle/input/commontest/dataset/train/sphere/9552.npy
# /kaggle/input/commontest/dataset/train/sphere/5655.npy
# /kaggle/input/commontest/dataset/train/sphere/8611.npy
# /kaggle/input/commontest/dataset/train/sphere/6534.npy
# /kaggle/input/commontest/dataset/train/sphere/5846.npy
# /kaggle/input/commontest/dataset/train/sphere/7390.npy
# /kaggle/input/commontest/dataset/train/sphere/1154.npy
# /kaggle/input/commontest/dataset/train/sphere/117.npy
# /kaggle/input/commontest/dataset/train/sphere/3295.npy
# /kaggle/input/commontest/dataset/train/sphere/1485.npy
# /kaggle/input/commontest/dataset/train/sphere/535.npy
# /kaggle/input/commontest/dataset/train/sphere/6775.npy
# /kaggle/input/commontest/dataset/train/sphere/5848.npy
# /kaggle/input/commontest/dataset/train/sphere/7645.npy
# /kaggle/input/commontest/dataset/train/sphere/1295.npy
# /kaggle/input/commontest/dataset/train/sphere/82.npy
# /kaggle/input/commontest/dataset/train/sphere/506.npy
# /kaggle/input/commontest/dataset/train/sphere/9427.npy
# /kaggle/input/commontest/dataset/train/sphere/5883.npy
# /kaggle/input/commontest/dataset/train/sphere/8360.npy
# /kaggle/input/commontest/dataset/train/sphere/5925.npy
# /kaggle/input/commontest/dataset/train/sphere/3183.npy
# /kaggle/input/commontest/dataset/train/sphere/6740.npy
# /kaggle/input/commontest/dataset/train/sphere/79.npy
# /kaggle/input/commontest/dataset/train/sphere/6653.npy
# /kaggle/input/commontest/dataset/train/sphere/9329.npy
# /kaggle/input/commontest/dataset/train/sphere/2337.npy
# /kaggle/input/commontest/dataset/train/sphere/2041.npy
# /kaggle/input/commontest/dataset/train/sphere/4286.npy
# /kaggle/input/commontest/dataset/train/sphere/7722.npy
# /kaggle/input/commontest/dataset/train/sphere/614.npy
# /kaggle/input/commontest/dataset/train/sphere/1259.npy
# /kaggle/input/commontest/dataset/train/sphere/141.npy
# /kaggle/input/commontest/dataset/train/sphere/9700.npy
# /kaggle/input/commontest/dataset/train/sphere/3523.npy
# /kaggle/input/commontest/dataset/train/sphere/5160.npy
# /kaggle/input/commontest/dataset/train/sphere/204.npy
# /kaggle/input/commontest/dataset/train/sphere/5075.npy
# /kaggle/input/commontest/dataset/train/sphere/5207.npy
# /kaggle/input/commontest/dataset/train/sphere/3608.npy
# /kaggle/input/commontest/dataset/train/sphere/5795.npy
# /kaggle/input/commontest/dataset/train/sphere/6368.npy
# /kaggle/input/commontest/dataset/train/sphere/7651.npy
# /kaggle/input/commontest/dataset/train/sphere/9425.npy
# /kaggle/input/commontest/dataset/train/sphere/2008.npy
# /kaggle/input/commontest/dataset/train/sphere/9630.npy
# /kaggle/input/commontest/dataset/train/sphere/8819.npy
# /kaggle/input/commontest/dataset/train/sphere/4154.npy
# /kaggle/input/commontest/dataset/train/sphere/6123.npy
# /kaggle/input/commontest/dataset/train/sphere/6233.npy
# /kaggle/input/commontest/dataset/train/sphere/1868.npy
# /kaggle/input/commontest/dataset/train/sphere/3057.npy
# /kaggle/input/commontest/dataset/train/sphere/2225.npy
# /kaggle/input/commontest/dataset/train/sphere/9848.npy
# /kaggle/input/commontest/dataset/train/sphere/4504.npy
# /kaggle/input/commontest/dataset/train/sphere/3740.npy
# /kaggle/input/commontest/dataset/train/sphere/5509.npy
# /kaggle/input/commontest/dataset/train/sphere/434.npy
# /kaggle/input/commontest/dataset/train/sphere/5442.npy
# /kaggle/input/commontest/dataset/train/sphere/532.npy
# /kaggle/input/commontest/dataset/train/sphere/9493.npy
# /kaggle/input/commontest/dataset/train/sphere/6553.npy
# /kaggle/input/commontest/dataset/train/sphere/2949.npy
# /kaggle/input/commontest/dataset/train/sphere/7695.npy
# /kaggle/input/commontest/dataset/train/sphere/7124.npy
# /kaggle/input/commontest/dataset/train/sphere/1789.npy
# /kaggle/input/commontest/dataset/train/sphere/9598.npy
# /kaggle/input/commontest/dataset/train/sphere/2591.npy
# /kaggle/input/commontest/dataset/train/sphere/1271.npy
# /kaggle/input/commontest/dataset/train/sphere/1881.npy
# /kaggle/input/commontest/dataset/train/sphere/6860.npy
# /kaggle/input/commontest/dataset/train/sphere/529.npy
# /kaggle/input/commontest/dataset/train/sphere/5403.npy
# /kaggle/input/commontest/dataset/train/sphere/1198.npy
# /kaggle/input/commontest/dataset/train/sphere/7672.npy
# /kaggle/input/commontest/dataset/train/sphere/3020.npy
# /kaggle/input/commontest/dataset/train/sphere/1033.npy
# /kaggle/input/commontest/dataset/train/sphere/7405.npy
# /kaggle/input/commontest/dataset/train/sphere/5145.npy
# /kaggle/input/commontest/dataset/train/sphere/9408.npy
# /kaggle/input/commontest/dataset/train/sphere/9020.npy
# /kaggle/input/commontest/dataset/train/sphere/594.npy
# /kaggle/input/commontest/dataset/train/sphere/3266.npy
# /kaggle/input/commontest/dataset/train/sphere/8135.npy
# /kaggle/input/commontest/dataset/train/sphere/523.npy
# /kaggle/input/commontest/dataset/train/sphere/4167.npy
# /kaggle/input/commontest/dataset/train/sphere/1231.npy
# /kaggle/input/commontest/dataset/train/sphere/8260.npy
# /kaggle/input/commontest/dataset/train/sphere/3276.npy
# /kaggle/input/commontest/dataset/train/sphere/179.npy
# /kaggle/input/commontest/dataset/train/sphere/541.npy
# /kaggle/input/commontest/dataset/train/sphere/8140.npy
# /kaggle/input/commontest/dataset/train/sphere/4156.npy

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, loguniform
from sklearn.metrics import (
    accuracy_score, 
    roc_auc_score, 
    roc_curve, 
    confusion_matrix,
    classification_report
)

# %%
class EfficientHyperparameterTuner:
    """Efficient Hyperparameter Tuning Framework"""
    def __init__(self, config_class, data_dir):
        self.config_class = config_class
        self.data_dir = data_dir
        
        # Define randomized search space
        self.param_distributions = {
            'lr': loguniform(1e-5, 1e-3),  # Log-uniform distribution for learning rate
            'batch_size': [32, 64, 128],
            'weight_decay': loguniform(1e-4, 1e-2),
            'model_name': ['resnet18', 'efficientnet_b0'],
            'dropout_rate': uniform(0.2, 0.5)
        }
    
    def tune(self, max_trials=10, epochs=5):
        """Efficient hyperparameter tuning"""
        best_score = 0
        best_config = None
        results = []
        
        # Prepare base dataset once
        train_df, val_df = self._prepare_base_data()
        
        for trial in range(max_trials):
            # Randomly sample hyperparameters
            params = self._sample_params()
            print(f"\n--- Trial {trial + 1} ---")
            print("Hyperparameters:", params)
            
            # Create configuration
            config = self._create_config(params, epochs)
            
            # Train and evaluate
            try:
                val_auc, trial_details = self._run_trial(config, train_df, val_df)
                
                # Store and track results
                result = {
                    'hyperparameters': params,
                    'val_auc': val_auc,
                    'details': trial_details
                }
                results.append(result)
                
                # Update best configuration
                if val_auc > best_score:
                    best_score = val_auc
                    best_config = params
                
                print(f"Validation AUC: {val_auc:.4f}")
            
            except Exception as e:
                print(f"Trial failed: {e}")
                continue
        
        # Visualize and save results
        self._analyze_results(results)
        
        return best_config, best_score
    
    def _prepare_base_data(self):
        """Prepare base dataset"""
        # Reuse data preparation logic from ModelTrainer
        trainer = ModelTrainer(self.config_class())
        return trainer.prepare_data(self.data_dir)
    
    def _sample_params(self):
        """Randomly sample hyperparameters"""
        return {
            'lr': self.param_distributions['lr'].rvs(),
            'batch_size': np.random.choice(self.param_distributions['batch_size']),
            'weight_decay': self.param_distributions['weight_decay'].rvs(),
            'model_name': np.random.choice(self.param_distributions['model_name']),
            'dropout_rate': self.param_distributions['dropout_rate'].rvs()
        }
    
    def _create_config(self, params, epochs):
        """Create configuration with sampled parameters"""
        config = self.config_class()
        config.lr = params['lr']
        config.batch_size = int(params['batch_size'])
        config.weight_decay = params['weight_decay']
        config.model_name = params['model_name']
        config.dropout_rate = params['dropout_rate']
        config.epochs = epochs
        return config
    
    def _run_trial(self, config, train_df, val_df):
        """Run a single trial with given configuration"""
        # Initialize trainer
        trainer = ModelTrainer(config)
        
        # Create data loaders
        train_loader, val_loader = trainer.create_dataloaders(train_df, val_df)
        
        # Train the model
        model, predictions, labels, history = trainer.train(train_loader, val_loader)
        
        # Calculate performance metric
        val_auc = history['val_auc'][-1]
        
        return val_auc, {
            'train_loss': history['train_loss'],
            'val_loss': history['val_loss'],
            'learning_rates': history['learning_rates']
        }
    
    def _analyze_results(self, results):
        """Analyze and visualize tuning results"""
        # Convert results to DataFrame
        df = pd.DataFrame([
            {**r['hyperparameters'], 'val_auc': r['val_auc']} 
            for r in results
        ])
        
        # Create visualization
        plt.figure(figsize=(15, 10))
        
        # Learning Rate vs Performance
        plt.subplot(2, 2, 1)
        sns.scatterplot(data=df, x='lr', y='val_auc', hue='model_name')
        plt.title('Learning Rate vs Performance')
        plt.xscale('log')
        
        # Batch Size vs Performance
        plt.subplot(2, 2, 2)
        sns.boxplot(data=df, x='batch_size', y='val_auc')
        plt.title('Batch Size vs Performance')
        
        # Weight Decay vs Performance
        plt.subplot(2, 2, 3)
        sns.scatterplot(data=df, x='weight_decay', y='val_auc', hue='model_name')
        plt.title('Weight Decay vs Performance')
        plt.xscale('log')
        
        # Model Name vs Performance
        plt.subplot(2, 2, 4)
        sns.boxplot(data=df, x='model_name', y='val_auc')
        plt.title('Model Architecture vs Performance')
        plt.xticks(rotation=45)
        
        plt.tight_layout()
        plt.savefig('hyperparameter_tuning_results.png')
        plt.close()

# %%
class ModelTrainer:
    """Optimized Model Trainer with Reduced Epochs"""
    def __init__(self, config):
        self.config = config
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def prepare_data(self, data_dir):
        """Prepare training and validation datasets"""
        def _get_image_paths(base_path, classes):
            paths = []
            labels = []
            for label, cls in enumerate(classes):
                class_path = os.path.join(base_path, cls)
                for img_file in os.listdir(class_path):
                    paths.append(os.path.join(class_path, img_file))
                    labels.append(label)
            return paths, labels

        # Directory 
        train_path = os.path.join(data_dir, 'train')
        classes = ['no', 'sphere', 'vort']
        
        paths, labels = _get_image_paths(train_path, classes)
        
        df = pd.DataFrame({
            'data_path': paths,
            'target': labels
        })
        
        # Split into train and validation
        train_df, val_df = train_test_split(
            df, 
            test_size=0.1, # 90 : 10 train-test split specified as per document 
            stratify=df['target'], 
            random_state=self.config.seed
        )
        
        return train_df, val_df

    def create_dataloaders(self, train_df, val_df):
        """Create PyTorch DataLoaders"""
        train_dataset = LensDataset(train_df)
        val_dataset = LensDataset(val_df)
        
        train_loader = DataLoader(
            train_dataset, 
            batch_size=self.config.batch_size, 
            shuffle=True, 
            num_workers=self.config.num_workers
        )
        
        val_loader = DataLoader(
            val_dataset, 
            batch_size=self.config.batch_size, 
            shuffle=False, 
            num_workers=self.config.num_workers
        )
        
        return train_loader, val_loader
    
    
    def train(self, train_loader, val_loader):
        """Streamlined training loop with early stopping"""
        # Initialize model with configurable dropout
        model = LensClassificationModel(self.config).to(self.device)
        
        # Loss and Optimizer
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.AdamW(
            model.parameters(), 
            lr=self.config.lr, 
            weight_decay=self.config.weight_decay
        )
        
        # Learning Rate Scheduler
        scheduler = ReduceLROnPlateau(
            optimizer, 
            mode='max',
            factor=0.5,
            patience=2,
            verbose=True
        )
        
        # Early Stopping
        patience = 3
        min_delta = 0.001
        best_val_auc = 0
        counter = 0
        
        # Training Tracking
        training_history = {
            'train_loss': [],
            'val_loss': [],
            'val_auc': [],
            'learning_rates': []
        }
        
        for epoch in range(self.config.epochs):
            # Training Phase
            model.train()
            train_losses = []
            
            for images, labels in train_loader:
                images, labels = images.to(self.device), labels.to(self.device)
                
                optimizer.zero_grad()
                outputs = model(images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                
                train_losses.append(loss.item())
            
            # Validation Phase
            model.eval()
            val_losses = []
            all_preds = []
            all_labels = []
            
            with torch.no_grad():
                for images, labels in val_loader:
                    images, labels = images.to(self.device), labels.to(self.device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    
                    val_losses.append(loss.item())
                    preds = torch.softmax(outputs, dim=1)
                    all_preds.append(preds.cpu().numpy())
                    all_labels.append(labels.cpu().numpy())
            
            # Aggregate predictions and labels
            all_preds = np.concatenate(all_preds)
            all_labels = np.concatenate(all_labels)
            
            # Calculate metrics
            val_auc = roc_auc_score(all_labels, all_preds, multi_class='ovr')
            
            # Log metrics
            avg_train_loss = np.mean(train_losses)
            avg_val_loss = np.mean(val_losses)
            
            training_history['train_loss'].append(avg_train_loss)
            training_history['val_loss'].append(avg_val_loss)
            training_history['val_auc'].append(val_auc)
            
            # Get current learning rate
            current_lr = optimizer.param_groups[0]['lr']
            training_history['learning_rates'].append(current_lr)
            
            # Learning Rate Scheduling
            scheduler.step(val_auc)
            
            # Early Stopping
            if val_auc > best_val_auc + min_delta:
                best_val_auc = val_auc
                counter = 0
                # Save best model
                torch.save({
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'best_val_auc': best_val_auc
                }, 'best_model.pth')
            else:
                counter += 1
            
            # Stop if no improvement
            if counter >= patience:
                print(f"Early stopping triggered after {epoch+1} epochs")
                break
            
            # Print epoch summary
            print(f"Epoch {epoch+1}/{self.config.epochs}")
            print(f"Train Loss: {avg_train_loss:.4f}")
            print(f"Val Loss: {avg_val_loss:.4f}")
            print(f"Val AUC: {val_auc:.4f}")
            print(f"Current LR: {current_lr:.6f}")
        
        return model, all_preds, all_labels, training_history

# %%
class ModelVisualizer:
    """Visualization utilities for model performance"""
    @staticmethod
    def plot_training_history(history, save_path='training_history.png'):
        """Plot training and validation loss/AUC"""
        plt.figure(figsize=(12, 4))
        
        # Loss Plot
        plt.subplot(1, 2, 1)
        plt.plot(history['train_loss'], label='Train Loss')
        plt.plot(history['val_loss'], label='Validation Loss')
        plt.title('Training and Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        # AUC Plot
        plt.subplot(1, 2, 2)
        plt.plot(history['val_auc'], label='Validation AUC', color='green')
        plt.title('Validation AUC')
        plt.xlabel('Epoch')
        plt.ylabel('AUC Score')
        plt.legend()
        
        plt.tight_layout()
        plt.savefig(save_path)
        plt.close()

    @staticmethod
    def plot_confusion_matrix(labels, predictions, class_names, save_path='confusion_matrix.png'):
        """Create and save confusion matrix visualization"""
        # Get predicted class labels
        pred_labels = np.argmax(predictions, axis=1)
        
        # Compute confusion matrix
        cm = confusion_matrix(labels, pred_labels)
        
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                    xticklabels=class_names, 
                    yticklabels=class_names)
        plt.title('Confusion Matrix')
        plt.xlabel('Predicted Label')
        plt.ylabel('True Label')
        plt.tight_layout()
        plt.savefig(save_path)
        plt.close()

    @staticmethod
    def plot_roc_curve(labels, predictions, class_names, save_path='roc_curve.png'):
        """Plot ROC curves for multiclass classification"""
        plt.figure(figsize=(10, 8))
        
        # One-vs-Rest ROC Curves
        for i in range(len(class_names)):
            # Create binary labels for current class
            binary_labels = (labels == i).astype(int)
            class_preds = predictions[:, i]
            
            # Compute ROC curve
            fpr, tpr, _ = roc_curve(binary_labels, class_preds)
            
            # Calculate AUC
            roc_auc = roc_auc_score(binary_labels, class_preds)
            
            # Plot ROC curve
            plt.plot(fpr, tpr, 
                     label=f'ROC curve (class: {class_names[i]}, AUC = {roc_auc:.2f})')
        
        plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic (ROC) Curve')
        plt.legend(loc="lower right")
        plt.tight_layout()
        plt.savefig(save_path)
        plt.close()

# %%
def main():
    # Configuration
    config_class = DeepLensConfig 
    data_dir = '/kaggle/input/commontest/dataset'
    
    # Defining classes explicitly
    CLASS_NAMES = ['no', 'sphere', 'vort']

    # Efficient Hyperparameter Tuning
    tuner = EfficientHyperparameterTuner(config_class, data_dir)
    best_config, best_score = tuner.tune(
        max_trials=10,  
        epochs=5        
    )

    print("\nBest Hyperparameters:")
    print(best_config)
    print(f"Best Validation AUC: {best_score:.4f}")


    # Manually Hardcoded afer Hyperparameter Tuning 
    BEST_PARAMS = {
        'lr':  0.0008936514993794424, # Learning rate
        'batch_size': 32,  # Batch size
        'weight_decay': 0.0001812043338125292, # Weight decay
        'model_name': 'efficientnet_b0', # Model architecture
        'dropout_rate': 0.4516472894261153   # Dropout rate
    }

    # Create configuration with manual parameters
    config = config_class()
    config.lr = BEST_PARAMS['lr']
    config.batch_size = BEST_PARAMS['batch_size']
    config.weight_decay = BEST_PARAMS['weight_decay']
    config.model_name = BEST_PARAMS['model_name']
    config.dropout_rate = BEST_PARAMS['dropout_rate']

    # Prepare data
    trainer = ModelTrainer(config)
    train_df, val_df = trainer.prepare_data(data_dir)
    
    # Create data loaders
    train_loader, val_loader = trainer.create_dataloaders(train_df, val_df)
    
    # Train model with best configuration
    model, predictions, labels, history = trainer.train(train_loader, val_loader)
    
    # Visualization
    visualizer = ModelVisualizer()
    
    # 1. Training History Plot
    visualizer.plot_training_history(history)
    
    # 2. Confusion Matrix (pass class names explicitly)
    visualizer.plot_confusion_matrix(labels, predictions, CLASS_NAMES)
    
    # 3. ROC Curves (pass class names explicitly)
    visualizer.plot_roc_curve(labels, predictions, CLASS_NAMES)
    
    # 4. Save Best Model with Additional Metadata
    model_save_path = 'best_model_full.pth'
    torch.save({
        'model_state_dict': model.state_dict(),
        'best_config': BEST_PARAMS,
        'class_names': CLASS_NAMES,
        'training_history': history
    }, model_save_path)
    
    # 5. Generate Detailed Performance Report
    print("\nDetailed Classification Report:")
    pred_labels = np.argmax(predictions, axis=1)
    print(classification_report(labels, pred_labels, target_names=CLASS_NAMES))

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/10
# Train Loss: 0.9088
# Val Loss: 0.7603
# Val AUC: 0.8725
# Current LR: 0.000894
# Epoch 2/10
# Train Loss: 0.5301
# Val Loss: 0.4182
# Val AUC: 0.9541
# Current LR: 0.000894
# Epoch 3/10
# Train Loss: 0.3739
# Val Loss: 0.3804
# Val AUC: 0.9643
# Current LR: 0.000894
# Epoch 4/10
# Train Loss: 0.3036
# Val Loss: 0.2956
# Val AUC: 0.9746
# Current LR: 0.000894
# Epoch 5/10
# Train Loss: 0.2528
# Val Loss: 0.2525
# Val AUC: 0.9809
# Current LR: 0.000894
# Epoch 6/10
# Train Loss: 0.2190
# Val Loss: 0.2620
# Val AUC: 0.9799
# Current LR: 0.000894
# Epoch 7/10
# Train Loss: 0.1933
# Val Loss: 0.2824
# Val AUC: 0.9786
# Current LR: 0.000894
# Epoch 8/10
# Train Loss: 0.1845
# Val Loss: 0.3115
# Val AUC: 0.9828
# Current LR: 0.000894
# Epoch 9/10
# Train Loss: 0.1533
# Val Loss: 0.3046
# Val AUC: 0.9803
# Current LR: 0.000894
# Epoch 10/10
# Train Loss: 0.1388
# Val Loss: 0.3205
# Val AUC: 0.9826
# Current LR: 0.000894
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#           no       0.86      0.99      0.92      1000
#       sphere       0.90      0.89      0.89      1000
#         vort       0.98      0.84      0.90      1000
#
#     accuracy                           0.91      3000
#    macro avg       0.91      0.91      0.90      3000
# weighted avg       0.91      0.91      0.90      3000
